# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# I amm only using the red wine dataset
data = pd.read_csv('./dataset/winequality-red-dot.csv')
y = data.quality                  # set 'quality' as target
X = data.drop('quality', axis=1)  # rest are features
print(y.shape, X.shape)           # check correctness.csv')
data.head()
# Out:
# (1599,) (1599, 11)
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# ...

# %%
# Let's proceed to separate 'quality' as the target variable and the rest as features.
y = data.quality                  # set 'quality' as target
X = data.drop('quality', axis=1)  # rest are features
print(y.shape, X.shape)           # check correctness
# Out:
# (1599,) (1599, 11)

# %%
#
# data.hist(figsize=(10,10))
sns.set()
data.hist(figsize=(10,10))
plt.show()

# %%
#feature relation
# %matplotlib inline
colormap = plt.cm.viridis
plt.figure(figsize=(12, 12))
plt.title('Correlation of Features', y=1.05, size=15, color="black")
sns.heatmap(data.astype(float).corr(), linewidths=0.1, vmax=1.0, square=True, cmap=colormap, 
            linecolor='white', annot=True)

plt.show()

# %%
# train data true label graph
pca_point = np.loadtxt("./encode/train_list.txt", delimiter=',')
label = np.loadtxt("./prediction/train_label.txt", delimiter=',')

max_x, min_x = max(pca_point[:, 0]), min(pca_point[:, 0])
max_y, min_y = max(pca_point[:, 1]), min(pca_point[:, 1])

plt.figure(figsize=(12, 12))

label_color = ['b', 'g', 'r', 'c', 'm', 'y']
for pid,point in enumerate(pca_point):
    plt.text(point[0], point[1],int(label[pid]), color=label_color[int(label[pid])-3])

plt.xlim(min_x, max_x)
plt.ylim(min_y, max_y)
plt.title("train true label")
plt.xticks([])
plt.yticks([])
print(max_x, min_x)
print(max_y, min_y)
plt.show()
# Out:
# 1667325.75 1060538.375
# -19547.0097656 -36291.2421875

# %%
# train data prediction graph
pca_point = np.loadtxt("./encode/train_list.txt", delimiter=',')
prediction = np.loadtxt("./prediction/train_prediction.txt", delimiter=',')

max_x, min_x = max(pca_point[:, 0]), min(pca_point[:, 0])
max_y, min_y = max(pca_point[:, 1]), min(pca_point[:, 1])

plt.figure(figsize=(12, 12))

label_color = ['b', 'g', 'r', 'c', 'm', 'y']
for pid,point in enumerate(pca_point):
    plt.text(point[0], point[1],int(prediction[pid]), color=label_color[int(prediction[pid])-3])

plt.xlim(min_x, max_x)
plt.ylim(min_y, max_y)
plt.title("train prediction")
plt.xticks([])
plt.yticks([])
print(max_x, min_x)
print(max_y, min_y)
plt.show()
# Out:
# 1667325.75 1060538.375
# -19547.0097656 -36291.2421875

# %%
# test data true label graph
pca_point = np.loadtxt("./encode/test_list.txt", delimiter=',')
label = np.loadtxt("./prediction/test_label.txt", delimiter=',')

max_x, min_x = max(pca_point[:, 0]), min(pca_point[:, 0])
max_y, min_y = max(pca_point[:, 1]), min(pca_point[:, 1])

plt.figure(figsize=(12, 12))

label_color = ['b', 'g', 'r', 'c', 'm', 'y']
for pid,point in enumerate(pca_point):
    plt.text(point[0], point[1],int(label[pid]), color=label_color[int(label[pid])-3])

plt.xlim(min_x, max_x)
plt.ylim(min_y, max_y)
plt.title("test true label")
plt.xticks([])
plt.yticks([])
print(max_x, min_x)
print(max_y, min_y)
plt.show()
# Out:
# 1636474.75 1135377.875
# -20831.5605469 -33120.1992188

# %%
# test data true prediction graph
pca_point = np.loadtxt("./encode/test_list.txt", delimiter=',')
prediction = np.loadtxt("./prediction/test_prediction.txt", delimiter=',')

max_x, min_x = max(pca_point[:, 0]), min(pca_point[:, 0])
max_y, min_y = max(pca_point[:, 1]), min(pca_point[:, 1])

plt.figure(figsize=(12, 12))

label_color = ['b', 'g', 'r', 'c', 'm', 'y']
for pid,point in enumerate(pca_point):
    plt.text(point[0], point[1],int(prediction[pid]), color=label_color[int(prediction[pid])-3])

plt.xlim(min_x, max_x)
plt.ylim(min_y, max_y)
plt.title("test prediction")
plt.xticks([])
plt.yticks([])
print(max_x, min_x)
print(max_y, min_y)
plt.show()
# Out:
# 1636474.75 1135377.875
# -20831.5605469 -33120.1992188
